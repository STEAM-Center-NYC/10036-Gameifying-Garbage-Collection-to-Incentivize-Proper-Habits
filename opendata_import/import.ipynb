# %%
import pandas as pd
import numpy as np

df = pd.read_csv("leafs.csv")
df['BinType'] = 'Leaf'

df
# Out:
#                                         Site Location  Zipcode DSNY Zone  \
# 0   1000 Richmond Terrace, NYC Compost Demonstrati...    10310        SI
# 1                               W 12th St and 8th Ave    10014        MN
# 2                   McGolrick Park (Greenpoint 11222)    11222       BKN
# 3                                  25-30 Skillman Ave    11101        QW
# 4            31-20, 31-98 54th St, Woodside, NY 11377    11377        QW
# 5                          252-256 Saint Marks Avenue    11238       BKN
# 6                  506 W 143rd St, New York, NY 10031    10031        MN
# 7                         69th Street and 35th Avenue    11377        QW
# 8                   139th street and St. Ann's avenue    10454        BX
# 9                  Seaman Ave and Isham St (N corner)    10034        MN
# 10                        69th Street and 35th Avenue    11377        QW
# 11                                 118 E 119th Street    10035        MN
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("recycle.csv")
df
# Out:
#     DSNY Zone DSNY District                                 Site Location  \
# 0         BKN         BKN02         120 SCHERMERHORN ST - INSIDE BUILDING
# 1         BKN         BKN02           141 LIVINGSTON ST - INSIDE BUILDING
# 2         BKN         BKN02                345 ADAMS ST - INSIDE BUILDING
# 3         BKN         BKN02                360 ADAMS ST - INSIDE BUILDING
# 4         BKN         BKN02                        6TH AVE & ATLANTIC AVE
# ..        ...           ...                                           ...
# 121        SI          SI02               FRANKLIN D. ROOSEVELT BOARDWALK
# 122        SI          SI02  2800 VICTORY BLVD - COLLEGE OF STATEN ISLAND
# 123        SI          SI03    222 POLLION AVE - BLUE HERON NATURE CENTER
# 124        SI          SI03               FRESH KILLS PARK VISITOR CENTER
# 125        SI          SI03                              GREAT KILLS PARK
#
#      BinType
# 0    Recycle
# 1    Recycle
# 2    Recycle
# 3    Recycle
# ...

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("syringepharma.csv")
df
# Out:
#            Borough  Zipcode                                   Site Location  \
# 0           Queens    11434    127-04 Guy R Brewer Blvd,  Queens,  NY 11434
# 1        Manhattan    10034              5141 Broadway, New York, NY, 10034
# 2           Queens    11369    101-22 Astoria Boulevard,  Queens,  NY 11369
# 3        Manhattan    10037     20 West 135th Street,  Manhattan,  NY 10037
# 4    Staten Island    10307      116 Main Street,  Staten Island,  NY 10307
# ..             ...      ...                                             ...
# 356  Staten Island    10301  78 Richmond Terrace,  Staten Island,  NY 10301
# 357       Brooklyn    11226         669 Manhattan Ave,  Brooklyn,  NY 11226
# 358       Brooklyn    11206             76 Graham Ave,  Brooklyn,  NY 11206
# 359       Brooklyn    11216            1281 Fulton St,  Brooklyn,  NY 11216
# 360      Manhattan    10037               30 W 138th St, New York, NY 10037
#
#     DSNY Zone  DSNY District   Latitude  Longitude  \
# ...

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("foodscrap.csv")
df
# Out:
#        Borough                         Site Location   Latitude  Longitude  \
# 0     Brooklyn   6753 4th Avenue, Brooklyn, NY 11220  40.635514 -74.022767
# 1    Manhattan                   E 47th St & 2nd Ave  40.752606 -73.969036
# 2    Manhattan  Pier 84 at W. 44th St. near dog park  40.763460 -74.000250
# 3    Manhattan                  127 East 58th Street  40.761980 -73.969300
# 4    Manhattan              Greenwich St. & Duane St  40.717424 -74.010793
# ..         ...                                   ...        ...        ...
# 586   Brooklyn                                   NaN  40.686570 -73.954486
# 587   Brooklyn                                   NaN  40.702068 -73.923838
# 588  Manhattan                                   NaN  40.850395 -73.934480
# 589  Manhattan                                   NaN  40.744130 -73.976231
# 590      Bronx                                   NaN  40.879899 -73.875879
#
# ...

# %%
import pandas as pd
import numpy as np


df = pd.read_csv("electronics.csv")
df
# Out:
#        Borough           Site Location  Zipcode DSNYZone DSNYDistrict  \
# 0    Manhattan             103 W 25 St    10001       MN         MN04
# 1    Manhattan               44 W 8 St    10011       MN         MN02
# 2       Queens         59-20 Grand Ave    11378       QW         QW05
# 3        Bronx  330-340 Baychester Ave    10475       BX         BX10
# 4       Queens     106-15 Sutphin Blvd    11435       QE         QE12
# ..         ...                     ...      ...      ...          ...
# 102  Manhattan              60 W 23 St    10010       MN         MN05
# 103  Manhattan               767 5 Ave    10153       MN         MN05
# 104  Manhattan           2248 Broadway    10024       MN         MN07
# 105   Brooklyn          535 Morgan Ave    11222      BKN        BKN01
# 106   Brooklyn        123 Flatbush Ave    11217      BKN        BKN02
#
#       Latitude  Longitude                                       point  \
# ...
